# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from sklearn.neural_network import MLPClassifier

# %%
df = pd.read_csv("credit_dataset.csv")

X = df[[
    "age",
    "income",
    "debt_to_income",
    "credit_score",
    "loan_amount"
]]

y = df["approved"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(32, 16),
    activation="relu",
    solver="adam",
    max_iter=500,
    random_state=42
)

mlp.fit(X_train_scaled, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(32, 16), max_iter=500, random_state=42)

# %%
y_pred_mlp = mlp.predict(X_test_scaled)

# %%
cm_mlp = confusion_matrix(y_test, y_pred_mlp)
cm_mlp
# Out:
# array([[1043,  157],
#        [ 117, 1683]])

# %%
cost_fp = 100
cost_fn = 10

TN, FP, FN, TP = cm_mlp.ravel()

expected_cost_mlp = FP * cost_fp + FN * cost_fn
cost_per_applicant_mlp = expected_cost_mlp / len(y_test)

expected_cost_mlp, cost_per_applicant_mlp
# Out:
# (16870, 5.623333333333333)

# %% [markdown]
# 1. The cost is increasing. The false positives are higher, the false negatives are lower.
# 2. No.
# 3. I am not sure about this. Maybe we can fine-tune the model to better optimize the output.
